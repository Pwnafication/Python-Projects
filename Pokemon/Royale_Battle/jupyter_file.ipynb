# %%
import requests

# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %%
url = "https://pokemondb.net/move/all"

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Pokémon moves: list of attacks | Pokémon Database</title>
# <link href="https://img.pokemondb.net" rel="preconnect"/>
# <style>@font-face{font-family:"Fira Sans";font-style:normal;font-weight:400;font-display:swap;src:url("/static/fonts/fira-sans-v10-latin-400.woff2") format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:"Fira Sans";font-style:italic;font-weight:400;font-display:swap;src:url("/static/fonts/fira-sans-v10-latin-400i.woff2") format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:"Fira Sans";font-style:normal;font-weight:700;font-display:swap;src:url("/static/fonts/fira-sans-v10-latin-600.woff2") format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:"Fira Sans";font-style:italic;font-weight:700;font-display:swap;src:url("/static/fonts/fira-sans-v10-latin-600i.woff2") format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}</style>
# <link href="/static/css/pokemondb-ba9dd1500d.css" rel="stylesheet"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="There are over 460 Pokémon attacks in total; this page lists every move with lots of detail. filter by name, type and category." name="description" property="og:description"/>
# <link href="https://pokemondb.net/move/all" rel="canonical"/>
# <meta content="https://pokemondb.net/move/all" property="og:url"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="Pokémon moves: list of attacks" property="og:title"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://pokemondb.net/news/feed" rel="alternate" title="The Pokémon Database newsfeed" type="application/rss+xml"/>
# <script>var localDbVersions = 220900;</script>
# <script defer="" src="/static/js/global-fa5cd4f984.js"></script>
# <script defer="" src="data:text/javascript;base64,..."></script>
# <script>
# (function(){
# 	var bsa_optimize=document.createElement('script');
# 	bsa_optimize.defer=true;
# 	bsa_optimize.src='https://cdn4.buysellads.net/pub/pokemondb.js?'+(new Date()-new Date()%600000);
# 	(document.getElementsByTagName('head')[0]||document.getElementsByTagName('body')[0]).appendChild(bsa_optimize);
# })();
# </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-B98MZQQDQR"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
# 	gtag('config', 'G-B98MZQQDQR');
# </script>
# <noscript>
# <style>.main-menu-item:hover > .main-menu-sub { visibility: visible; opacity: 1; }</style>
# </noscript>
# </head>
# <body>
# <a class="sr-only" href="#main">Skip to main content</a>
# <header class="main-header">
# <div class="grid-container">
# <a class="header-logo" href="/">
# <picture>
# <source media="(min-width: 900px)" srcset="https://img.pokemondb.net/design/avif/header-lg.avif" type="image/avif">
# <source media="(min-width: 620px)" srcset="https://img.pokemondb.net/design/avif/header-md.avif, https://img.pokemondb.net/design/avif/header-md-2x.avif 2x" type="image/avif">
# <source srcset="https://img.pokemondb.net/design/avif/header-sm.avif, https://img.pokemondb.net/design/avif/header-sm-2x.avif 2x" type="image/avif">
# <source media="(min-width: 900px)" srcset="https://img.pokemondb.net/design/header-lg.png" type="image/png">
# <source media="(min-width: 620px)" srcset="https://img.pokemondb.net/design/header-md.png, https://img.pokemondb.net/design/header-md-2x.png 2x" type="image/png">
# <img src="https://img.pokemondb.net/design/header-sm.png" srcset="https://img.pokemondb.net/design/header-sm-2x.png 2x"/>
# </source></source></source></source></source></picture>
# </a>
# </div>
# </header>
# <nav class="main-menu grid-container">
# <ul class="main-menu-list">
# <li class="main-menu-item">
# <a class="main-menu-heading" href="/sitemap">
# <svg aria-label="Pokeball icon" class="main-menu-icon img-fixed" height="24" role="img" viewbox="0 0 512 512" width="24" xmlns="http://www.w3.org/2000/svg"><g fill="#a3a3a3"><path d="M229.7 36.8A220.9 220.9 0 0 0 37.5 224.9l-.4 4.3h106.5l1.4-4.7a116.3 116.3 0 0 1 73-77.5 114.7 114.7 0 0 1 149 79l.9 3.2H475l-1.7-10.1A220 220 0 0 0 281 36.7c-12-1.4-39.3-1.4-51.2 0z"></path><path d="M239.7 185a74 74 0 0 0-49.7 40.3 73 73 0 0 0 15.4 82.3 72.1 72.1 0 0 0 101.9-1.2 68.8 68.8 0 0 0 20.6-50.7 69.1 69.1 0 0 0-21-51.2 73.3 73.3 0 0 0-33-19c-7.6-2.1-26.4-2.3-34.2-.5z"></path><path d="M37.5 286.3a220.5 220.5 0 0 0 436 4.5l1.5-8.9H367.9l-1 3.2a130 130 0 0 1-17.7 37.6 144 144 0 0 1-26.9 26.8 142 142 0 0 1-30.7 15.4 96.3 96.3 0 0 1-35.8 5.3 90 90 0 0 1-22.5-1.7 114 114 0 0 1-58.6-31.7 110.1 110.1 0 0 1-28.3-46l-2.9-8.9H37l.6 4.4h-.1z"></path></g></svg> <span class="main-menu-title">Data</span>
# <span class="main-menu-title-long">Pokémon data</span>
# </a>
# <ul class="main-menu-sub">
# <li><a href="/pokedex">Pokédex</a></li>
# <li><a href="/move">Moves</a></li>
# <li><a href="/type">Type chart</a></li>
# <li><a href="/ability">Abilities</a></li>
# <li><a href="/item">Items</a></li>
# <li><a href="/evolution">Evolution chains</a></li>
# <li><a href="/location">Pokémon locations</a></li>
# <li><a href="/sprites">Sprite gallery</a></li>
# <li class="main-menu-hr-title">Quick links</li>
# <li><a href="/pokedex/national">National Pokédex</a></li>
# <li><a href="/pokedex/all">Pokémon list with stats</a></li>
# <li><a href="/pokedex/game/brilliant-diamond-shining-pearl">BD &amp; SP Pokédex</a></li>
# <li><a href="/pokedex/game/legends-arceus">Legends: Arceus Pokédex</a></li>
# </ul>
# </li>
# <li class="main-menu-item">
# <a class="main-menu-heading" href="/sitemap">
# <svg aria-label="Mechanics icon" class="main-menu-icon img-fixed" height="24" role="img" viewbox="0 0 512 512" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M479.5 297.5v-82l-50.3-8.4a156.5 156.5 0 0 0-16-38.3l30-40.8-57.7-58.8-42 29c-12-6.5-25-12.2-38.2-15.9L297 33h-82l-8.3 50.3a163 163 0 0 0-38.3 16l-41-29.1L68.8 128l29.9 41A184 184 0 0 0 82.8 208l-50.3 7.4v82l50.3 8.3a163 163 0 0 0 16 38.3l-30 41.7 57.6 57.6 42-29.7a184 184 0 0 0 39 15.8l8.4 49.5h82l8.3-50.4c13.1-3.7 26-9.3 38.3-15.8l41.9 29.8 57.6-57.8-29.7-42c6.4-12 12-24 15.8-38.1l49.3-7.4.2.2zM255.8 342c-47.5 0-85.7-38.3-85.7-85.7s39.1-85.7 85.7-85.7 85.8 38.3 85.8 85.7-38.3 85.7-85.8 85.7z" fill="#a3a3a3"></path></svg> <span class="main-menu-title">Mechanics</span>
# <span class="main-menu-title-long">Game mechanics</span>
# </a>
# <ul class="main-menu-sub">
# <li><a href="/mechanics/breeding">Breeding &amp; egg groups</a></li>
# <li><a href="/mechanics/move-tutors">Move Tutors</a></li>
# <li><a href="/type/dual">Dual type chart</a></li>
# <li><a href="/ev">Effort Values (EVs)</a></li>
# <li><a href="/mechanics/natures">Natures</a></li>
# <li><a href="/mechanics/hidden">IVs/Personality</a></li>
# <li class="main-menu-hr-title">Useful tools</li>
# <li><a href="/tools/moveset-search">Moveset searcher</a></li>
# <li><a href="/tools/type-coverage">Type coverage checker</a></li>
# </ul>
# </li>
# <li class="main-menu-item">
# <a class="main-menu-heading" href="/sitemap">
# <svg aria-label="Game controller icon" class="main-menu-icon img-fixed" height="24" role="img" viewbox="0 0 512 512" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M117.4 121.9c-104.8 14.6-152 142.6-82.2 222.9 48 55 131.9 62.7 187.2 17l4.6-3.8H285l4.6 3.7c55.3 45.8 139.3 38.2 187.2-17 70.2-80.6 22.4-208.6-83.1-222.9-14.8-2-261.9-2-276.2 0m42.8 52.8c2.2 2.2 2.2 2.7 2.5 29.4l.3 27.2h53.5l2.4 2.5c3.8 3.8 3.8 40.8 0 44.6l-2.4 2.4H163l-.3 27.2c-.4 35 2.2 31.7-25 31.7-27.3 0-24.7 3.3-25-31.7l-.4-27.2H59l-2.4-2.4c-3.9-3.8-3.9-40.8 0-44.6l2.4-2.5h53.4l.3-27c.4-35-1.8-32.4 26.3-32 18.3.1 19 .2 21.3 2.4m259.3 16.5a33.7 33.7 0 0 1 19.5 42.5 33.2 33.2 0 0 1-59 5.8c-16.4-26.6 9.7-58.4 39.5-48.3M352 259a33 33 0 0 1 3.7 60 32.7 32.7 0 0 1-48-27.3A32.9 32.9 0 0 1 352 259" fill="#a3a3a3" fill-rule="evenodd"></path></svg> <span class="main-menu-title">Games</span>
# <span class="main-menu-title-long">Pokémon games</span>
# </a>
# <ul class="main-menu-sub">
# <li><a href="/scarlet-violet">Scarlet &amp; Violet</a></li>
# <li><a href="/go">Pokémon GO</a></li>
# <li class="main-menu-hr"></li>
# <li><a href="/legends-arceus">Legends: Arceus</a></li>
# <li><a href="/brilliant-diamond-shining-pearl">Brilliant Diamond &amp; Shining Pearl</a></li>
# <li><a href="/sword-shield">Sword &amp; Shield</a></li>
# <li class="main-menu-hr"></li>
# <li><a href="/lets-go-pikachu-eevee">Let's Go Pikachu &amp; Let's Go Eevee</a></li>
# <li><a href="/ultra-sun-ultra-moon">Ultra Sun &amp; Ultra Moon</a></li>
# <li><a href="/sun-moon">Sun &amp; Moon</a></li>
# <li class="main-menu-hr"></li>
# <li><a href="/omega-ruby-alpha-sapphire">Omega Ruby &amp; Alpha Sapphire</a></li>
# <li><a href="/x-y">X &amp; Y</a></li>
# <li class="main-menu-hr"></li>
# <li><a href="/black-white-2">Black 2 &amp; White 2</a></li>
# <li><a href="/black-white">Black &amp; White</a></li>
# <li class="main-menu-hr"></li>
# <li><a href="/heartgold-soulsilver">HeartGold &amp; SoulSilver</a></li>
# <li><a href="/platinum">Platinum</a></li>
# <li><a href="/diamond-pearl">Diamond &amp; Pearl</a></li>
# <li class="main-menu-hr"></li>
# <li><a href="/emerald">Emerald</a></li>
# <li><a href="/firered-leafgreen">FireRed &amp; LeafGreen</a></li>
# <li><a href="/ruby-sapphire">Ruby &amp; Sapphire</a></li>
# <li class="main-menu-hr"></li>
# <li><a href="/crystal">Crystal</a></li>
# <li><a href="/gold-silver">Gold &amp; Silver</a></li>
# <li class="main-menu-hr"></li>
# <li><a href="/yellow">Yellow</a></li>
# <li><a href="/red-blue">Red &amp; Blue</a></li>
# <li class="main-menu-hr"></li>
# <li><a href="/spinoff">Spin-off games</a></li>
# </ul>
# </li>
# <li class="main-menu-item">
# <a class="main-menu-heading" href="/sitemap">
# <svg aria-label="Chat icon" class="main-menu-icon img-fixed" height="24" role="img" viewbox="0 0 512 512" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M36.5 95v241.5a44.5 44.5 0 0 0 43.9 43.9h58.5v73.1a7.3 7.3 0 0 0 12.8 5l71-78.1h208.9a44.5 44.5 0 0 0 43.9-44V95a44.5 44.5 0 0 0-43.9-43.9H80.4a44.5 44.5 0 0 0-43.9 44zm292.7 117.1a29.3 29.3 0 1 1 58.6 0 29.3 29.3 0 0 1-58.6 0zm-102.5 0a29.3 29.3 0 1 1 58.6 0 29.3 29.3 0 0 1-58.6 0zm-102.4 0a29.3 29.3 0 1 1 58.6 0 29.3 29.3 0 0 1-58.6 0z" fill="#a3a3a3"></path></svg> <span class="main-menu-title">Other</span>
# <span class="main-menu-title-long">Community/Other</span>
# </a>
# <ul class="main-menu-sub">
# <li><a href="/pokebase/">Pokémon Q&amp;A</a></li>
# <li><a href="/pokebase/rmt/">Pokémon Rate My Team</a></li>
# <li><a href="/pokebase/chat">Chat Room</a></li>
# <li><a href="/pokebase/meta/">Meta (Suggestion Box)</a></li>
# <li class="main-menu-hr-title">Other pages</li>
# <li><a href="/">Pokémon News</a></li>
# <li><a href="/maps">Maps/Puzzles</a></li>
# <li><a href="/etymology">Pokémon name origins</a></li>
# <li><a href="/about">About/Contact us</a></li>
# </ul>
# </li>
# <li class="main-menu-item main-menu-item-search">
# <form action="/search" class="sitesearch-form" method="get">
# <label class="sr-only" for="sitesearch">Search</label>
# <input autocomplete="off" class="input-text sitesearch-input" id="sitesearch" name="q" placeholder="Search" tabindex="100" type="text"/>
# <svg aria-label="Search" class="main-menu-icon img-fixed" height="20" role="img" viewbox="0 0 512 512" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M495.6 466.4L373.8 339.6a206 206 0 0 0 48.5-132.9C422.3 92.7 329.5 0 215.6 0S8.8 92.7 8.8 206.7s92.8 206.7 206.8 206.7c42.8 0 83.5-12.9 118.4-37.4l122.8 127.7a26.8 26.8 0 0 0 38.1.8 27 27 0 0 0 .7-38.1zm-280-412.5c84.2 0 152.8 68.6 152.8 152.8s-68.6 152.8-152.8 152.8S62.8 291 62.8 206.7 131.3 54 215.6 54z" fill="#a3a3a3"></path></svg> <div class="sitesearch-results"></div>
# </form>
# </li>
# </ul>
# </nav>
# <main class="main-content grid-container" id="main">
# <h1>Pokémon move list</h1>
# <div class="panel panel-intro">
# <p>This is a full list of <em>every Pokémon move</em> from all 8 generations of the game series.
# The power, accuracy and PP are listed along with any additional effects.</p>
# <p>Click a move name to see even more detailed information, including which Pokémon can learn that move. You
# can click a column heading to instantly sort by that column, or filter on move name, type and category
# using the options provided.</p>
# <p>Category key:
# <img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/> Physical
# <img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/> Special
# <img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/> Status
# </p>
# </div>
# <div class="component text-center" style="min-height:90px"><div id="bsa-zone_1642018196755-7_123456"></div></div>
# <div class="table-filters">
# <label for="filter-move-name">Name/Effect:</label>
# <input class="input-text" data-filter-col="0,7" id="filter-move-name" tabindex="2" type="text"/>
# <label for="filter-move-type">Type:</label>
# <select data-filter-col="1" data-filter-hash="type" id="filter-move-type" tabindex="3">
# <option value="">- All -</option>
# <option value="normal">Normal</option>
# <option value="fire">Fire</option>
# <option value="water">Water</option>
# <option value="electric">Electric</option>
# <option value="grass">Grass</option>
# <option value="ice">Ice</option>
# <option value="fighting">Fighting</option>
# <option value="poison">Poison</option>
# <option value="ground">Ground</option>
# <option value="flying">Flying</option>
# <option value="psychic">Psychic</option>
# <option value="bug">Bug</option>
# <option value="rock">Rock</option>
# <option value="ghost">Ghost</option>
# <option value="dragon">Dragon</option>
# <option value="dark">Dark</option>
# <option value="steel">Steel</option>
# <option value="fairy">Fairy</option>
# </select>
# <label for="filter-move-cat">Category:</label>
# <select data-filter-col="2" data-filter-hash="cat" id="filter-move-cat" tabindex="4">
# <option value="">- All -</option>
# <option value="physical">Physical</option>
# <option value="special">Special</option>
# <option value="status">Status</option>
# </select>
# </div>
# <div class="resp-scroll">
# <table class="data-table sticky-header block-wide" id="moves">
# <thead>
# <tr>
# <th class="sorting" data-sort="string"><div class="sortwrap">Name</div></th> <th class="sorting" data-sort="string"><div class="sortwrap">Type</div></th> <th class="sorting" data-sort="string"><div class="sortwrap">Cat.</div></th> <th class="sorting" data-blanks="1" data-sort="int"><div class="sortwrap">Power</div></th> <th class="sorting" data-blanks="1" data-sort="int"><div class="sortwrap">Acc.</div></th> <th class="sorting" data-blanks="1" data-sort="int"><div class="sortwrap">PP</div></th> <th class="sorting" data-blanks="1" data-sort="int"><div class="sortwrap">TM</div></th> <th><div class="sortwrap">Effect</div></th> <th class="sorting" data-blanks="1" data-sort="int"><div class="sortwrap">Prob. (%)</div></th> </tr>
# </thead>
# <tbody>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/10000000-volt-thunderbolt" title="View details for 10,000,000 Volt Thunderbolt">10,000,000 Volt Thunderbolt</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">195</td> <td class="cell-num">—</td> <td class="cell-num">1</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Pikachu-exclusive Z-Move. High critical hit ratio.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/absorb" title="View details for Absorb">Absorb</a></td><td class="cell-icon"><a class="type-icon type-grass" href="/type/grass">Grass</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">20</td> <td class="cell-num">100</td> <td class="cell-num">25</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User recovers half the HP inflicted on opponent.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/accelerock" title="View details for Accelerock">Accelerock</a></td><td class="cell-icon"><a class="type-icon type-rock" href="/type/rock">Rock</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">40</td> <td class="cell-num">100</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User attacks first.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/acid" title="View details for Acid">Acid</a></td><td class="cell-icon"><a class="type-icon type-poison" href="/type/poison">Poison</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">40</td> <td class="cell-num">100</td> <td class="cell-num">30</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May lower opponent's Special Defense.</td>
# <td class="cell-num">10</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/acid-armor" title="View details for Acid Armor">Acid Armor</a></td><td class="cell-icon"><a class="type-icon type-poison" href="/type/poison">Poison</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Sharply raises user's Defense.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/acid-downpour" title="View details for Acid Downpour">Acid Downpour</a></td><td class="cell-icon"><a class="type-icon type-poison" href="/type/poison">Poison</a></td><td class="cell-icon text-center" data-filter-value="" data-sort-value="">—</td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">1</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Poison type Z-Move.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/acid-spray" title="View details for Acid Spray">Acid Spray</a></td><td class="cell-icon"><a class="type-icon type-poison" href="/type/poison">Poison</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">40</td> <td class="cell-num">100</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Sharply lowers opponent's Special Defense.</td>
# <td class="cell-num">100</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/acrobatics" title="View details for Acrobatics">Acrobatics</a></td><td class="cell-icon"><a class="type-icon type-flying" href="/type/flying">Flying</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">55</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Stronger when the user does not have a held item.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/acupressure" title="View details for Acupressure">Acupressure</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">30</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Sharply raises a random stat.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aerial-ace" title="View details for Aerial Ace">Aerial Ace</a></td><td class="cell-icon"><a class="type-icon type-flying" href="/type/flying">Flying</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num num-infinity" data-sort-value="101">∞</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Ignores Accuracy and Evasiveness.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aeroblast" title="View details for Aeroblast">Aeroblast</a></td><td class="cell-icon"><a class="type-icon type-flying" href="/type/flying">Flying</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">100</td> <td class="cell-num">95</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">High critical hit ratio.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/after-you" title="View details for After You">After You</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Gives target priority in the next turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/agility" title="View details for Agility">Agility</a></td><td class="cell-icon"><a class="type-icon type-psychic" href="/type/psychic">Psychic</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">30</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Sharply raises user's Speed.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/air-cutter" title="View details for Air Cutter">Air Cutter</a></td><td class="cell-icon"><a class="type-icon type-flying" href="/type/flying">Flying</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num">95</td> <td class="cell-num">25</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">High critical hit ratio.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/air-slash" title="View details for Air Slash">Air Slash</a></td><td class="cell-icon"><a class="type-icon type-flying" href="/type/flying">Flying</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">75</td> <td class="cell-num">95</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May cause flinching.</td>
# <td class="cell-num">30</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/all-out-pummeling" title="View details for All-Out Pummeling">All-Out Pummeling</a></td><td class="cell-icon"><a class="type-icon type-fighting" href="/type/fighting">Fighting</a></td><td class="cell-icon text-center" data-filter-value="" data-sort-value="">—</td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">1</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Fighting type Z-Move.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/ally-switch" title="View details for Ally Switch">Ally Switch</a></td><td class="cell-icon"><a class="type-icon type-psychic" href="/type/psychic">Psychic</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User switches with opposite teammate.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/amnesia" title="View details for Amnesia">Amnesia</a></td><td class="cell-icon"><a class="type-icon type-psychic" href="/type/psychic">Psychic</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Sharply raises user's Special Defense.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/anchor-shot" title="View details for Anchor Shot">Anchor Shot</a></td><td class="cell-icon"><a class="type-icon type-steel" href="/type/steel">Steel</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num">100</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">The user entangles the target with its anchor chain while attacking. The target becomes unable to flee.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/ancient-power" title="View details for Ancient Power">Ancient Power</a></td><td class="cell-icon"><a class="type-icon type-rock" href="/type/rock">Rock</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num">100</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May raise all user's stats at once.</td>
# <td class="cell-num">10</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/apple-acid" title="View details for Apple Acid">Apple Acid</a></td><td class="cell-icon"><a class="type-icon type-grass" href="/type/grass">Grass</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Lowers target's Special Defense.</td>
# <td class="cell-num">100</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aqua-jet" title="View details for Aqua Jet">Aqua Jet</a></td><td class="cell-icon"><a class="type-icon type-water" href="/type/water">Water</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">40</td> <td class="cell-num">100</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User attacks first.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aqua-ring" title="View details for Aqua Ring">Aqua Ring</a></td><td class="cell-icon"><a class="type-icon type-water" href="/type/water">Water</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Restores a little HP each turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aqua-tail" title="View details for Aqua Tail">Aqua Tail</a></td><td class="cell-icon"><a class="type-icon type-water" href="/type/water">Water</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">90</td> <td class="cell-num">90</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text"></td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/arm-thrust" title="View details for Arm Thrust">Arm Thrust</a></td><td class="cell-icon"><a class="type-icon type-fighting" href="/type/fighting">Fighting</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">15</td> <td class="cell-num">100</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Hits 2-5 times in one turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aromatherapy" title="View details for Aromatherapy">Aromatherapy</a></td><td class="cell-icon"><a class="type-icon type-grass" href="/type/grass">Grass</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Cures all status problems in your party.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aromatic-mist" title="View details for Aromatic Mist">Aromatic Mist</a></td><td class="cell-icon"><a class="type-icon type-fairy" href="/type/fairy">Fairy</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Raises Special Defense of an ally.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/assist" title="View details for Assist">Assist</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User performs a move known by its allies at random.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/assurance" title="View details for Assurance">Assurance</a></td><td class="cell-icon"><a class="type-icon type-dark" href="/type/dark">Dark</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Power doubles if opponent already took damage in the same turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/astonish" title="View details for Astonish">Astonish</a></td><td class="cell-icon"><a class="type-icon type-ghost" href="/type/ghost">Ghost</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">30</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May cause flinching.</td>
# <td class="cell-num">30</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/astral-barrage" title="View details for Astral Barrage">Astral Barrage</a></td><td class="cell-icon"><a class="type-icon type-ghost" href="/type/ghost">Ghost</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">120</td> <td class="cell-num">100</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">The user attacks by sending a frightful amount of small ghosts at opposing Pokémon.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/attack-order" title="View details for Attack Order">Attack Order</a></td><td class="cell-icon"><a class="type-icon type-bug" href="/type/bug">Bug</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">90</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">High critical hit ratio.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/attract" title="View details for Attract">Attract</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">If opponent is the opposite gender, it's less likely to attack.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aura-sphere" title="View details for Aura Sphere">Aura Sphere</a></td><td class="cell-icon"><a class="type-icon type-fighting" href="/type/fighting">Fighting</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num num-infinity" data-sort-value="101">∞</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Ignores Accuracy and Evasiveness.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aura-wheel" title="View details for Aura Wheel">Aura Wheel</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">110</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Changes type based on Morpeko's Mode.</td>
# <td class="cell-num">100</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aurora-beam" title="View details for Aurora Beam">Aurora Beam</a></td><td class="cell-icon"><a class="type-icon type-ice" href="/type/ice">Ice</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">65</td> <td class="cell-num">100</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May lower opponent's Attack.</td>
# <td class="cell-num">10</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aurora-veil" title="View details for Aurora Veil">Aurora Veil</a></td><td class="cell-icon"><a class="type-icon type-ice" href="/type/ice">Ice</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Halves damage from Physical and Special attacks for five turns.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/autotomize" title="View details for Autotomize">Autotomize</a></td><td class="cell-icon"><a class="type-icon type-steel" href="/type/steel">Steel</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Reduces weight and sharply raises Speed.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/avalanche" title="View details for Avalanche">Avalanche</a></td><td class="cell-icon"><a class="type-icon type-ice" href="/type/ice">Ice</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Power doubles if user took damage first.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/baby-doll-eyes" title="View details for Baby-Doll Eyes">Baby-Doll Eyes</a></td><td class="cell-icon"><a class="type-icon type-fairy" href="/type/fairy">Fairy</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">100</td> <td class="cell-num">30</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Always goes first. Lowers the target's attack.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/baddy-bad" title="View details for Baddy Bad">Baddy Bad</a></td><td class="cell-icon"><a class="type-icon type-dark" href="/type/dark">Dark</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">90</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Reduces damage from Physical attacks.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/baneful-bunker" title="View details for Baneful Bunker">Baneful Bunker</a></td><td class="cell-icon"><a class="type-icon type-poison" href="/type/poison">Poison</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Protects the user and poisons opponent on contact.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/barb-barrage" title="View details for Barb Barrage">Barb Barrage</a></td><td class="cell-icon"><a class="type-icon type-poison" href="/type/poison">Poison</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Inflicts double damage if the target has a status condition.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/barrage" title="View details for Barrage">Barrage</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">15</td> <td class="cell-num">85</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Hits 2-5 times in one turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/barrier" title="View details for Barrier">Barrier</a></td><td class="cell-icon"><a class="type-icon type-psychic" href="/type/psychic">Psychic</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Sharply raises user's Defense.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/baton-pass" title="View details for Baton Pass">Baton Pass</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">40</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User switches out and gives stat changes to the incoming Pokémon.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# ...
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Move's power and type changes with the weather.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/whirlpool" title="View details for Whirlpool">Whirlpool</a></td><td class="cell-icon"><a class="type-icon type-water" href="/type/water">Water</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">35</td> <td class="cell-num">85</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Traps opponent, damaging them for 4-5 turns.</td>
# <td class="cell-num">100</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/whirlwind" title="View details for Whirlwind">Whirlwind</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">In battles, the opponent switches. In the wild, the Pokémon runs.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wicked-blow" title="View details for Wicked Blow">Wicked Blow</a></td><td class="cell-icon"><a class="type-icon type-dark" href="/type/dark">Dark</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num">100</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Always results in a critical hit and ignores stat changes.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wide-guard" title="View details for Wide Guard">Wide Guard</a></td><td class="cell-icon"><a class="type-icon type-rock" href="/type/rock">Rock</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Protects the user's team from multi-target attacks.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wild-charge" title="View details for Wild Charge">Wild Charge</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">90</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User receives recoil damage.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wildbolt-storm" title="View details for Wildbolt Storm">Wildbolt Storm</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">95</td> <td class="cell-num">80</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May paralyze target.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/will-o-wisp" title="View details for Will-O-Wisp">Will-O-Wisp</a></td><td class="cell-icon"><a class="type-icon type-fire" href="/type/fire">Fire</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">85</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Burns opponent.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wing-attack" title="View details for Wing Attack">Wing Attack</a></td><td class="cell-icon"><a class="type-icon type-flying" href="/type/flying">Flying</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num">100</td> <td class="cell-num">35</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text"></td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wish" title="View details for Wish">Wish</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">The user recovers HP in the following turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/withdraw" title="View details for Withdraw">Withdraw</a></td><td class="cell-icon"><a class="type-icon type-water" href="/type/water">Water</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">40</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Raises user's Defense.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wonder-room" title="View details for Wonder Room">Wonder Room</a></td><td class="cell-icon"><a class="type-icon type-psychic" href="/type/psychic">Psychic</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Swaps every Pokémon's Defense and Special Defense for 5 turns.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wood-hammer" title="View details for Wood Hammer">Wood Hammer</a></td><td class="cell-icon"><a class="type-icon type-grass" href="/type/grass">Grass</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">120</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User receives recoil damage.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/work-up" title="View details for Work Up">Work Up</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">30</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Raises user's Attack and Special Attack.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/worry-seed" title="View details for Worry Seed">Worry Seed</a></td><td class="cell-icon"><a class="type-icon type-grass" href="/type/grass">Grass</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Changes the opponent's Ability to Insomnia.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wrap" title="View details for Wrap">Wrap</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">15</td> <td class="cell-num">90</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Traps opponent, damaging them for 4-5 turns.</td>
# <td class="cell-num">100</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wring-out" title="View details for Wring Out">Wring Out</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">100</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">The higher the opponent's HP, the higher the damage.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/x-scissor" title="View details for X-Scissor">X-Scissor</a></td><td class="cell-icon"><a class="type-icon type-bug" href="/type/bug">Bug</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text"></td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/yawn" title="View details for Yawn">Yawn</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Puts opponent to sleep in the next turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/zap-cannon" title="View details for Zap Cannon">Zap Cannon</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">120</td> <td class="cell-num">50</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Paralyzes opponent.</td>
# <td class="cell-num">100</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/zen-headbutt" title="View details for Zen Headbutt">Zen Headbutt</a></td><td class="cell-icon"><a class="type-icon type-psychic" href="/type/psychic">Psychic</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num">90</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May cause flinching.</td>
# <td class="cell-num">20</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/zing-zap" title="View details for Zing Zap">Zing Zap</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May cause flinching.</td>
# <td class="cell-num">30</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/zippy-zap" title="View details for Zippy Zap">Zippy Zap</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">50</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Always results in a critical hit.</td>
# <td class="cell-num">100</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="component text-center" style="min-height:90px"><div id="bsa-zone_1612827518798-2_123456"></div></div>
# </main>
# <footer class="main-footer">
# <div class="grid-container">
# <a class="wrap-right" href="/about#privacy">Privacy Policy</a>
# All content &amp; design © Pokémon Database, 2008-2022.
# Pokémon images &amp; names © 1995-2022 Nintendo/Game Freak.
# </div>
# </footer>
# </body>
# </html>

# %%
table1 = soup.find('table',{'id':'moves'})
print(table1)
# Out:
# <table class="data-table sticky-header block-wide" id="moves">
# <thead>
# <tr>
# <th class="sorting" data-sort="string"><div class="sortwrap">Name</div></th> <th class="sorting" data-sort="string"><div class="sortwrap">Type</div></th> <th class="sorting" data-sort="string"><div class="sortwrap">Cat.</div></th> <th class="sorting" data-blanks="1" data-sort="int"><div class="sortwrap">Power</div></th> <th class="sorting" data-blanks="1" data-sort="int"><div class="sortwrap">Acc.</div></th> <th class="sorting" data-blanks="1" data-sort="int"><div class="sortwrap">PP</div></th> <th class="sorting" data-blanks="1" data-sort="int"><div class="sortwrap">TM</div></th> <th><div class="sortwrap">Effect</div></th> <th class="sorting" data-blanks="1" data-sort="int"><div class="sortwrap">Prob. (%)</div></th> </tr>
# </thead>
# <tbody>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/10000000-volt-thunderbolt" title="View details for 10,000,000 Volt Thunderbolt">10,000,000 Volt Thunderbolt</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">195</td> <td class="cell-num">—</td> <td class="cell-num">1</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Pikachu-exclusive Z-Move. High critical hit ratio.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/absorb" title="View details for Absorb">Absorb</a></td><td class="cell-icon"><a class="type-icon type-grass" href="/type/grass">Grass</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">20</td> <td class="cell-num">100</td> <td class="cell-num">25</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User recovers half the HP inflicted on opponent.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/accelerock" title="View details for Accelerock">Accelerock</a></td><td class="cell-icon"><a class="type-icon type-rock" href="/type/rock">Rock</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">40</td> <td class="cell-num">100</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User attacks first.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/acid" title="View details for Acid">Acid</a></td><td class="cell-icon"><a class="type-icon type-poison" href="/type/poison">Poison</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">40</td> <td class="cell-num">100</td> <td class="cell-num">30</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May lower opponent's Special Defense.</td>
# <td class="cell-num">10</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/acid-armor" title="View details for Acid Armor">Acid Armor</a></td><td class="cell-icon"><a class="type-icon type-poison" href="/type/poison">Poison</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Sharply raises user's Defense.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/acid-downpour" title="View details for Acid Downpour">Acid Downpour</a></td><td class="cell-icon"><a class="type-icon type-poison" href="/type/poison">Poison</a></td><td class="cell-icon text-center" data-filter-value="" data-sort-value="">—</td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">1</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Poison type Z-Move.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/acid-spray" title="View details for Acid Spray">Acid Spray</a></td><td class="cell-icon"><a class="type-icon type-poison" href="/type/poison">Poison</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">40</td> <td class="cell-num">100</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Sharply lowers opponent's Special Defense.</td>
# <td class="cell-num">100</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/acrobatics" title="View details for Acrobatics">Acrobatics</a></td><td class="cell-icon"><a class="type-icon type-flying" href="/type/flying">Flying</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">55</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Stronger when the user does not have a held item.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/acupressure" title="View details for Acupressure">Acupressure</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">30</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Sharply raises a random stat.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aerial-ace" title="View details for Aerial Ace">Aerial Ace</a></td><td class="cell-icon"><a class="type-icon type-flying" href="/type/flying">Flying</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num num-infinity" data-sort-value="101">∞</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Ignores Accuracy and Evasiveness.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aeroblast" title="View details for Aeroblast">Aeroblast</a></td><td class="cell-icon"><a class="type-icon type-flying" href="/type/flying">Flying</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">100</td> <td class="cell-num">95</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">High critical hit ratio.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/after-you" title="View details for After You">After You</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Gives target priority in the next turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/agility" title="View details for Agility">Agility</a></td><td class="cell-icon"><a class="type-icon type-psychic" href="/type/psychic">Psychic</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">30</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Sharply raises user's Speed.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/air-cutter" title="View details for Air Cutter">Air Cutter</a></td><td class="cell-icon"><a class="type-icon type-flying" href="/type/flying">Flying</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num">95</td> <td class="cell-num">25</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">High critical hit ratio.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/air-slash" title="View details for Air Slash">Air Slash</a></td><td class="cell-icon"><a class="type-icon type-flying" href="/type/flying">Flying</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">75</td> <td class="cell-num">95</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May cause flinching.</td>
# <td class="cell-num">30</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/all-out-pummeling" title="View details for All-Out Pummeling">All-Out Pummeling</a></td><td class="cell-icon"><a class="type-icon type-fighting" href="/type/fighting">Fighting</a></td><td class="cell-icon text-center" data-filter-value="" data-sort-value="">—</td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">1</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Fighting type Z-Move.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/ally-switch" title="View details for Ally Switch">Ally Switch</a></td><td class="cell-icon"><a class="type-icon type-psychic" href="/type/psychic">Psychic</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User switches with opposite teammate.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/amnesia" title="View details for Amnesia">Amnesia</a></td><td class="cell-icon"><a class="type-icon type-psychic" href="/type/psychic">Psychic</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Sharply raises user's Special Defense.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/anchor-shot" title="View details for Anchor Shot">Anchor Shot</a></td><td class="cell-icon"><a class="type-icon type-steel" href="/type/steel">Steel</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num">100</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">The user entangles the target with its anchor chain while attacking. The target becomes unable to flee.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/ancient-power" title="View details for Ancient Power">Ancient Power</a></td><td class="cell-icon"><a class="type-icon type-rock" href="/type/rock">Rock</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num">100</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May raise all user's stats at once.</td>
# <td class="cell-num">10</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/apple-acid" title="View details for Apple Acid">Apple Acid</a></td><td class="cell-icon"><a class="type-icon type-grass" href="/type/grass">Grass</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Lowers target's Special Defense.</td>
# <td class="cell-num">100</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aqua-jet" title="View details for Aqua Jet">Aqua Jet</a></td><td class="cell-icon"><a class="type-icon type-water" href="/type/water">Water</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">40</td> <td class="cell-num">100</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User attacks first.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aqua-ring" title="View details for Aqua Ring">Aqua Ring</a></td><td class="cell-icon"><a class="type-icon type-water" href="/type/water">Water</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Restores a little HP each turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aqua-tail" title="View details for Aqua Tail">Aqua Tail</a></td><td class="cell-icon"><a class="type-icon type-water" href="/type/water">Water</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">90</td> <td class="cell-num">90</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text"></td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/arm-thrust" title="View details for Arm Thrust">Arm Thrust</a></td><td class="cell-icon"><a class="type-icon type-fighting" href="/type/fighting">Fighting</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">15</td> <td class="cell-num">100</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Hits 2-5 times in one turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aromatherapy" title="View details for Aromatherapy">Aromatherapy</a></td><td class="cell-icon"><a class="type-icon type-grass" href="/type/grass">Grass</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Cures all status problems in your party.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aromatic-mist" title="View details for Aromatic Mist">Aromatic Mist</a></td><td class="cell-icon"><a class="type-icon type-fairy" href="/type/fairy">Fairy</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Raises Special Defense of an ally.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/assist" title="View details for Assist">Assist</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User performs a move known by its allies at random.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/assurance" title="View details for Assurance">Assurance</a></td><td class="cell-icon"><a class="type-icon type-dark" href="/type/dark">Dark</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Power doubles if opponent already took damage in the same turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/astonish" title="View details for Astonish">Astonish</a></td><td class="cell-icon"><a class="type-icon type-ghost" href="/type/ghost">Ghost</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">30</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May cause flinching.</td>
# <td class="cell-num">30</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/astral-barrage" title="View details for Astral Barrage">Astral Barrage</a></td><td class="cell-icon"><a class="type-icon type-ghost" href="/type/ghost">Ghost</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">120</td> <td class="cell-num">100</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">The user attacks by sending a frightful amount of small ghosts at opposing Pokémon.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/attack-order" title="View details for Attack Order">Attack Order</a></td><td class="cell-icon"><a class="type-icon type-bug" href="/type/bug">Bug</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">90</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">High critical hit ratio.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/attract" title="View details for Attract">Attract</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">If opponent is the opposite gender, it's less likely to attack.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aura-sphere" title="View details for Aura Sphere">Aura Sphere</a></td><td class="cell-icon"><a class="type-icon type-fighting" href="/type/fighting">Fighting</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num num-infinity" data-sort-value="101">∞</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Ignores Accuracy and Evasiveness.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aura-wheel" title="View details for Aura Wheel">Aura Wheel</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">110</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Changes type based on Morpeko's Mode.</td>
# <td class="cell-num">100</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aurora-beam" title="View details for Aurora Beam">Aurora Beam</a></td><td class="cell-icon"><a class="type-icon type-ice" href="/type/ice">Ice</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">65</td> <td class="cell-num">100</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May lower opponent's Attack.</td>
# <td class="cell-num">10</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/aurora-veil" title="View details for Aurora Veil">Aurora Veil</a></td><td class="cell-icon"><a class="type-icon type-ice" href="/type/ice">Ice</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Halves damage from Physical and Special attacks for five turns.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/autotomize" title="View details for Autotomize">Autotomize</a></td><td class="cell-icon"><a class="type-icon type-steel" href="/type/steel">Steel</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Reduces weight and sharply raises Speed.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/avalanche" title="View details for Avalanche">Avalanche</a></td><td class="cell-icon"><a class="type-icon type-ice" href="/type/ice">Ice</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Power doubles if user took damage first.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/baby-doll-eyes" title="View details for Baby-Doll Eyes">Baby-Doll Eyes</a></td><td class="cell-icon"><a class="type-icon type-fairy" href="/type/fairy">Fairy</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">100</td> <td class="cell-num">30</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Always goes first. Lowers the target's attack.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/baddy-bad" title="View details for Baddy Bad">Baddy Bad</a></td><td class="cell-icon"><a class="type-icon type-dark" href="/type/dark">Dark</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">90</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Reduces damage from Physical attacks.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/baneful-bunker" title="View details for Baneful Bunker">Baneful Bunker</a></td><td class="cell-icon"><a class="type-icon type-poison" href="/type/poison">Poison</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Protects the user and poisons opponent on contact.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/barb-barrage" title="View details for Barb Barrage">Barb Barrage</a></td><td class="cell-icon"><a class="type-icon type-poison" href="/type/poison">Poison</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Inflicts double damage if the target has a status condition.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/barrage" title="View details for Barrage">Barrage</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">15</td> <td class="cell-num">85</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Hits 2-5 times in one turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/barrier" title="View details for Barrier">Barrier</a></td><td class="cell-icon"><a class="type-icon type-psychic" href="/type/psychic">Psychic</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Sharply raises user's Defense.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/baton-pass" title="View details for Baton Pass">Baton Pass</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">40</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User switches out and gives stat changes to the incoming Pokémon.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/beak-blast" title="View details for Beak Blast">Beak Blast</a></td><td class="cell-icon"><a class="type-icon type-flying" href="/type/flying">Flying</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">100</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">The user first heats up its beak, and then it attacks the target. Making direct contact with the Pokémon while it's heating up its beak results in a burn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/beat-up" title="View details for Beat Up">Beat Up</a></td><td class="cell-icon"><a class="type-icon type-dark" href="/type/dark">Dark</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Each Pokémon in user's party attacks.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/behemoth-bash" title="View details for Behemoth Bash">Behemoth Bash</a></td><td class="cell-icon"><a class="type-icon type-steel" href="/type/steel">Steel</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">100</td> <td class="cell-num">100</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Damage doubles if target is Dynamaxed.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/behemoth-blade" title="View details for Behemoth Blade">Behemoth Blade</a></td><td class="cell-icon"><a class="type-icon type-steel" href="/type/steel">Steel</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">100</td> <td class="cell-num">100</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Damage doubles if target is Dynamaxed.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/belch" title="View details for Belch">Belch</a></td><td class="cell-icon"><a class="type-icon type-poison" href="/type/poison">Poison</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">120</td> <td class="cell-num">90</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User must have consumed a Berry.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/belly-drum" title="View details for Belly Drum">Belly Drum</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User loses 50% of its max HP, but Attack raises to maximum.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/bestow" title="View details for Bestow">Bestow</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Gives the user's held item to the target.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/bide" title="View details for Bide">Bide</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User takes damage for two turns then strikes back double.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/bind" title="View details for Bind">Bind</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">15</td> <td class="cell-num">85</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Traps opponent, damaging them for 4-5 turns.</td>
# <td class="cell-num">100</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/bite" title="View details for Bite">Bite</a></td><td class="cell-icon"><a class="type-icon type-dark" href="/type/dark">Dark</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num">100</td> <td class="cell-num">25</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May cause flinching.</td>
# <td class="cell-num">30</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/bitter-malice" title="View details for Bitter Malice">Bitter Malice</a></td><td class="cell-icon"><a class="type-icon type-ghost" href="/type/ghost">Ghost</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Inflicts double damage if the target has a status condition.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/black-hole-eclipse" title="View details for Black Hole Eclipse">Black Hole Eclipse</a></td><td class="cell-icon"><a class="type-icon type-dark" href="/type/dark">Dark</a></td><td class="cell-icon text-center" data-filter-value="" data-sort-value="">—</td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">1</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Dark type Z-Move.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/blast-burn" title="View details for Blast Burn">Blast Burn</a></td><td class="cell-icon"><a class="type-icon type-fire" href="/type/fire">Fire</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">150</td> <td class="cell-num">90</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User must recharge next turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/blaze-kick" title="View details for Blaze Kick">Blaze Kick</a></td><td class="cell-icon"><a class="type-icon type-fire" href="/type/fire">Fire</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">85</td> <td class="cell-num">90</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">High critical hit ratio. May burn opponent.</td>
# <td class="cell-num">10</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/bleakwind-storm" title="View details for Bleakwind Storm">Bleakwind Storm</a></td><td class="cell-icon"><a class="type-icon type-flying" href="/type/flying">Flying</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">95</td> <td class="cell-num">80</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May cause frostbite.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/blizzard" title="View details for Blizzard">Blizzard</a></td><td class="cell-icon"><a class="type-icon type-ice" href="/type/ice">Ice</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">110</td> <td class="cell-num">70</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May freeze opponent.</td>
# <td class="cell-num">10</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/block" title="View details for Block">Block</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Opponent cannot flee or switch.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/bloom-doom" title="View details for Bloom Doom">Bloom Doom</a></td><td class="cell-icon"><a class="type-icon type-grass" href="/type/grass">Grass</a></td><td class="cell-icon text-center" data-filter-value="" data-sort-value="">—</td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">1</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Grass type Z-Move.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/blue-flare" title="View details for Blue Flare">Blue Flare</a></td><td class="cell-icon"><a class="type-icon type-fire" href="/type/fire">Fire</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">130</td> <td class="cell-num">85</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May burn opponent.</td>
# <td class="cell-num">20</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/body-press" title="View details for Body Press">Body Press</a></td><td class="cell-icon"><a class="type-icon type-fighting" href="/type/fighting">Fighting</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">The higher the user's Defense, the stronger the attack.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/body-slam" title="View details for Body Slam">Body Slam</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">85</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May paralyze opponent.</td>
# <td class="cell-num">30</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/bolt-beak" title="View details for Bolt Beak">Bolt Beak</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">85</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# ...
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Move's power and type changes with the weather.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/whirlpool" title="View details for Whirlpool">Whirlpool</a></td><td class="cell-icon"><a class="type-icon type-water" href="/type/water">Water</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">35</td> <td class="cell-num">85</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Traps opponent, damaging them for 4-5 turns.</td>
# <td class="cell-num">100</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/whirlwind" title="View details for Whirlwind">Whirlwind</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">In battles, the opponent switches. In the wild, the Pokémon runs.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wicked-blow" title="View details for Wicked Blow">Wicked Blow</a></td><td class="cell-icon"><a class="type-icon type-dark" href="/type/dark">Dark</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num">100</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Always results in a critical hit and ignores stat changes.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wide-guard" title="View details for Wide Guard">Wide Guard</a></td><td class="cell-icon"><a class="type-icon type-rock" href="/type/rock">Rock</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Protects the user's team from multi-target attacks.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wild-charge" title="View details for Wild Charge">Wild Charge</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">90</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User receives recoil damage.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wildbolt-storm" title="View details for Wildbolt Storm">Wildbolt Storm</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">95</td> <td class="cell-num">80</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May paralyze target.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/will-o-wisp" title="View details for Will-O-Wisp">Will-O-Wisp</a></td><td class="cell-icon"><a class="type-icon type-fire" href="/type/fire">Fire</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">85</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Burns opponent.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wing-attack" title="View details for Wing Attack">Wing Attack</a></td><td class="cell-icon"><a class="type-icon type-flying" href="/type/flying">Flying</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">60</td> <td class="cell-num">100</td> <td class="cell-num">35</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text"></td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wish" title="View details for Wish">Wish</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">The user recovers HP in the following turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/withdraw" title="View details for Withdraw">Withdraw</a></td><td class="cell-icon"><a class="type-icon type-water" href="/type/water">Water</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">40</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Raises user's Defense.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wonder-room" title="View details for Wonder Room">Wonder Room</a></td><td class="cell-icon"><a class="type-icon type-psychic" href="/type/psychic">Psychic</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Swaps every Pokémon's Defense and Special Defense for 5 turns.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wood-hammer" title="View details for Wood Hammer">Wood Hammer</a></td><td class="cell-icon"><a class="type-icon type-grass" href="/type/grass">Grass</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">120</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">User receives recoil damage.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/work-up" title="View details for Work Up">Work Up</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">30</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Raises user's Attack and Special Attack.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/worry-seed" title="View details for Worry Seed">Worry Seed</a></td><td class="cell-icon"><a class="type-icon type-grass" href="/type/grass">Grass</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Changes the opponent's Ability to Insomnia.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wrap" title="View details for Wrap">Wrap</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">15</td> <td class="cell-num">90</td> <td class="cell-num">20</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Traps opponent, damaging them for 4-5 turns.</td>
# <td class="cell-num">100</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/wring-out" title="View details for Wring Out">Wring Out</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">100</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">The higher the opponent's HP, the higher the damage.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/x-scissor" title="View details for X-Scissor">X-Scissor</a></td><td class="cell-icon"><a class="type-icon type-bug" href="/type/bug">Bug</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text"></td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/yawn" title="View details for Yawn">Yawn</a></td><td class="cell-icon"><a class="type-icon type-normal" href="/type/normal">Normal</a></td><td class="cell-icon text-center" data-filter-value="status" data-sort-value="status"><img alt="Status" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-status.png" title="Status" width="30"/></td> <td class="cell-num">—</td> <td class="cell-num">—</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Puts opponent to sleep in the next turn.</td>
# <td class="cell-num">—</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/zap-cannon" title="View details for Zap Cannon">Zap Cannon</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="special" data-sort-value="special"><img alt="Special" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-special.png" title="Special" width="30"/></td> <td class="cell-num">120</td> <td class="cell-num">50</td> <td class="cell-num">5</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Paralyzes opponent.</td>
# <td class="cell-num">100</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/zen-headbutt" title="View details for Zen Headbutt">Zen Headbutt</a></td><td class="cell-icon"><a class="type-icon type-psychic" href="/type/psychic">Psychic</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num">90</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May cause flinching.</td>
# <td class="cell-num">20</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/zing-zap" title="View details for Zing Zap">Zing Zap</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">80</td> <td class="cell-num">100</td> <td class="cell-num">10</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">May cause flinching.</td>
# <td class="cell-num">30</td>
# </tr>
# <tr>
# <td class="cell-name"><a class="ent-name" href="/move/zippy-zap" title="View details for Zippy Zap">Zippy Zap</a></td><td class="cell-icon"><a class="type-icon type-electric" href="/type/electric">Electric</a></td><td class="cell-icon text-center" data-filter-value="physical" data-sort-value="physical"><img alt="Physical" class="img-fixed" height="20" loading="lazy" src="https://img.pokemondb.net/images/icons/move-physical.png" title="Physical" width="30"/></td> <td class="cell-num">50</td> <td class="cell-num">100</td> <td class="cell-num">15</td>
# <td class="cell-num" data-sort-value="0"></td>
# <td class="cell-long-text">Always results in a critical hit.</td>
# <td class="cell-num">100</td>
# </tr>
# </tbody>
# </table>

# %%
headers = []

# %%
for XX in table1.find_all('th'):
    title = XX.text
    headers.append(title)

# %%
mydata = pd.DataFrame(columns=headers)

# %%
for XX in table1.find_all('tr')[1:]:
    row_data = XX.find_all('td')
    row = [YY.text for YY in row_data]
    length = len(mydata)
    mydata.loc[length] = row

# %%
print(mydata)
# Out:
#                             Name      Type Cat. Power Acc.  PP TM  \
# 0    10,000,000 Volt Thunderbolt  Electric        195    —   1
# 1                         Absorb     Grass         20  100  25
# 2                     Accelerock      Rock         40  100  20
# 3                           Acid    Poison         40  100  30
# 4                     Acid Armor    Poison          —    —  20
# ..                           ...       ...  ...   ...  ...  .. ..
# 860                         Yawn    Normal          —    —  10
# 861                   Zap Cannon  Electric        120   50   5
# 862                 Zen Headbutt   Psychic         80   90  15
# 863                     Zing Zap  Electric         80  100  10
# 864                    Zippy Zap  Electric         50  100  15
#
#                                                 Effect Prob. (%)
# 0    Pikachu-exclusive Z-Move. High critical hit ra...         —
# 1     User recovers half the HP inflicted on opponent.         —
# 2                                  User attacks first.         —
# 3                May lower opponent's Special Defense.        10
# 4                       Sharply raises user's Defense.         —
# ..                                                 ...       ...
# 860           Puts opponent to sleep in the next turn.         —
# 861                                Paralyzes opponent.       100
# 862                               May cause flinching.        20
# 863                               May cause flinching.        30
# 864                  Always results in a critical hit.       100
#
# [865 rows x 9 columns]

# %%
mydata.head(10)
# Out:
#                           Name      Type Cat. Power Acc.  PP TM  \
# 0  10,000,000 Volt Thunderbolt  Electric        195    —   1
# 1                       Absorb     Grass         20  100  25
# 2                   Accelerock      Rock         40  100  20
# 3                         Acid    Poison         40  100  30
# 4                   Acid Armor    Poison          —    —  20
# 5                Acid Downpour    Poison    —     —    —   1
# 6                   Acid Spray    Poison         40  100  20
# 7                   Acrobatics    Flying         55  100  15
# 8                  Acupressure    Normal          —    —  30
# 9                   Aerial Ace    Flying         60    ∞  20
#
#                                               Effect Prob. (%)
# 0  Pikachu-exclusive Z-Move. High critical hit ra...         —
# 1   User recovers half the HP inflicted on opponent.         —
# 2                                User attacks first.         —
# 3              May lower opponent's Special Defense.        10
# 4                     Sharply raises user's Defense.         —
# 5                                Poison type Z-Move.         —
# 6         Sharply lowers opponent's Special Defense.       100
# 7  Stronger when the user does not have a held item.         —
# 8                      Sharply raises a random stat.         —
# 9                  Ignores Accuracy and Evasiveness.         —

# %%
mydata.loc[0][0]
# Out:
# '10,000,000 Volt Thunderbolt'

# %%
data = df.to_json(orient='records')

# %%
print(data)
# Out:
# [{"Name":"Zippy Zap","Type":"Electric","Cat.":"","Power":"50","Acc.":"100","PP":"15","TM":"","Effect":"Always results in a critical hit.","Prob. (%)":"100"},{"Name":"10,000,000 Volt Thunderbolt","Type":"Electric","Cat.":"","Power":"195","Acc.":"\u2014","PP":"1","TM":"","Effect":"Pikachu-exclusive Z-Move. High critical hit ratio.","Prob. (%)":"\u2014"},{"Name":"Absorb","Type":"Grass","Cat.":"","Power":"20","Acc.":"100","PP":"25","TM":"","Effect":"User recovers half the HP inflicted on opponent.","Prob. (%)":"\u2014"},{"Name":"Accelerock","Type":"Rock","Cat.":"","Power":"40","Acc.":"100","PP":"20","TM":"","Effect":"User attacks first.","Prob. (%)":"\u2014"},{"Name":"Acid","Type":"Poison","Cat.":"","Power":"40","Acc.":"100","PP":"30","TM":"","Effect":"May lower opponent's Special Defense.","Prob. (%)":"10"},{"Name":"Acid Armor","Type":"Poison","Cat.":"","Power":"\u2014","Acc.":"\u2014","PP":"20","TM":"","Effect":"Sharply raises user's Defense.","Prob. (%)":"\u2014"},{"Name":"Acid Downpour","Type":"Poison","Cat.":"\u2014","Power":"\u2014","Acc.":"\u2014","PP":"1","TM":"","Effect":"Poison type Z-Move.","Prob. (%)":"\u2014"},{"Name":"Acid Spray","Type":"Poison","Cat.":"","Power":"40","Acc.":"100","PP":"20","TM":"","Effect":"Sharply lowers opponent's Special Defense.","Prob. (%)":"100"},{"Name":"Acrobatics","Type":"Flying","Cat.":"","Power":"55","Acc.":"100","PP":"15","TM":"","Effect":"Stronger when the user does not have a held item.","Prob. (%)":"\u2014"},{"Name":"Acupressure","Type":"Normal","Cat.":"","Power":"\u2014","Acc.":"\u2014","PP":"30","TM":"","Effect":"Sharply raises a random stat.","Prob. (%)":"\u2014"},{"Name":"Aerial Ace","Type":"Flying","Cat.":"","Power":"60","Acc.":"\u221e","PP":"20","TM":"","Effect":"Ignores Accuracy and Evasiveness.","Prob. (%)":"\u2014"},{"Name":"Aeroblast","Type":"Flying","Cat.":"","Power":"100","Acc.":"95","PP":"5","TM":"","Effect":"High critical hit ratio.","Prob. (%)":"\u2014"},{"Name":"After You","Type":"Normal","Cat.":"","Power":"\u2014","Acc.":"\u2014","PP":"15","TM":"","Effect":"Gives target priority in the next turn.","Prob. (%)":"\u2014"},{"Name":"Agility","Type":"Psychic","Cat.":"","Power":"\u2014","Acc.":"\u2014","PP":"30","TM":"","Effect":"Sharply raises user's Speed.","Prob. (%)":"\u2014"},{"Name":"Air Cutter","Type":"Flying","Cat.":"","Power":"60","Acc.":"95","PP":"25","TM":"","Effect":"High critical hit ratio.","Prob. (%)":"\u2014"},{"Name":"Air Slash","Type":"Flying","Cat.":"","Power":"75","Acc.":"95","PP":"15","TM":"","Effect":"May cause flinching.","Prob. (%)":"30"},{"Name":"All-Out Pummeling","Type":"Fighting","Cat.":"\u2014","Power":"\u2014","Acc.":"\u2014","PP":"1","TM":"","Effect":"Fighting type Z-Move.","Prob. (%)":"\u2014"},{"Name":"Ally Switch","Type":"Psychic","Cat.":"","Power":"\u2014","Acc.":"\u2014","PP":"15","TM":"","Effect":"User switches with opposite teammate.","Prob. (%)":"\u2014"},{"Name":"Amnesia","Type":"Psychic","Cat.":"","Power":"\u2014","Acc.":"\u2014","PP":"20","TM":"","Effect":"Sharply raises user's Special Defense.","Prob. (%)":"\u2014"},{"Name":"Anchor Shot","Type":"Steel","Cat.":"","Power":"80","Acc.":"100","PP":"20","TM":"","Effect":"The user entangles the target with its anchor chain while attacking. The target becomes unable to flee.","Prob. (%)":"\u2014"},{"Name":"Ancient Power","Type":"Rock","Cat.":"","Power":"60","Acc.":"100","PP":"5","TM":"","Effect":"May raise all user's stats at once.","Prob. (%)":"10"},{"Name":"Apple Acid","Type":"Grass","Cat.":"","Power":"80","Acc.":"100","PP":"10","TM":"","Effect":"Lowers target's Special Defense.","Prob. (%)":"100"},{"Name":"Aqua Jet","Type":"Water","Cat.":"","Power":"40","Acc.":"100","PP":"20","TM":"","Effect":"User attacks first.","Prob. (%)":"\u2014"},{"Name":"Aqua Ring","Type":"Water","Cat.":"","Power":"\u2014","Acc.":"\u2014","PP":"20","TM":"","Effect":"Restores a little HP each turn.","Prob. (%)":"\u2014"},{"Name":"Aqua Tail","Type":"Water","Cat.":"","Power":"90","Acc.":"90","PP":"10","TM":"","Effect ...
